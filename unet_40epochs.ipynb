# %% [markdown]
# # Instructions

# %% [markdown]
# Run this notebook to:
# * Load a vgg16 model pretrained on the cifar10 dataset, from the "pretrainedmodel" folder.
# * Use this pretrained model to perform "Filter Pruning via Geometric Median". The pruned model is fine-tuned for 40 epochs. The pruning is done iteratively. So far the parameters are only zeroed out. The pruned model at this stage is saved as "vgg_cifar10_pruned_net.pth" in the present working directory.
# * Finally, architecture modifications are performed and the final pruned model is saved as "vgg_cifar10_arch_pruned_net.pth" in the present working directory.

# %% [markdown]
# # Selecting device

# %%
#%pip install torch 
import torch 
import torch.nn as nn

device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
    print("GPU Available")
# Out:
# GPU Available

# %%
! CUDA_VISIBLE_DEVICES=0
#! python ./fpgmdata/testing/pruning_cifar_vgg.py  ./fpgmdata/testing/data/cifar.python --dataset cifar10 --arch vgg --save_path ./logs/vgg_prune_precfg_varience4 --rate_norm 1 --rate_dist 0.2
! python  ./fpgmdata/testing/pruning_unet.py  ./fpgmdata/testing/data/carvana --dataset CARVANA --arch UNet --save_path ./logs/unet_pretrain/prune_precfg_epoch40_varience1 --rate_norm 1 --rate_dist 0.2 --use_pretrain --pretrain_path ./pretrainedmodel/MODEL.pth --use_state_dict --lr 0.001 --epochs 5 --use_precfg
# Out:
# save path : ./logs/unet_pretrain/prune_precfg_epoch40_varience1
# {'arch': 'UNet', 'batch_size': 1, 'cuda': True, 'data_path': './fpgmdata/testing/data/carvana', 'dataset': 'CARVANA', 'depth': 16, 'dist_type': 'l2', 'epoch_prune': 1, 'epochs': 40, 'evaluate': False, 'layer_begin': 1, 'layer_end': 1, 'layer_inter': 1, 'log_interval': 100, 'lr': 0.001, 'momentum': 0.9, 'no_cuda': False, 'pretrain_path': './pretrainedmodel/MODEL.pth', 'rate_dist': 0.2, 'rate_norm': 1.0, 'resume': '', 'save_path': './logs/unet_pretrain/prune_precfg_epoch40_varience1', 'seed': 1, 'start_epoch': 0, 'test_batch_size': 1, 'use_precfg': True, 'use_pretrain': True, 'use_state_dict': True, 'weight_decay': 0.0001}
# Random Seed: 1
# python version : 3.8.5 (default, Sep  4 2020, 07:30:14)  [GCC 7.3.0]
# torch  version : 1.12.0+cu102
# cudnn  version : 7605
# Norm Pruning Rate: 1.0
# Distance Pruning Rate: 0.2
# Layer Begin: 1
# Layer End: 1
# Layer Inter: 1
# Epoch prune: 1
# use pretrain: True
# Pretrain path: ./pretrainedmodel/MODEL.pth
# Dist type: l2
# Pre cfg: True
# 100%|███████████████████████████████████████| 5088/5088 [04:03<00:00, 20.87it/s]
# Prakalp Debug DATASET: 100
# Prakalp Debug TRAIN, TEST: <class 'torch.utils.data.dataset.Subset'>
# Prakalp Debug TRAIN, TEST: <torch.utils.data.dataset.Subset object at 0x7f4d2a89f670>
# Prakalp Debug loader_args: {'batch_size': 1, 'num_workers': 6, 'pin_memory': True}
# Prakalp Debug TRAIn LOADER: 80
# Prakalp Debug TEST LOADER: 20
# => creating model 'UNet'
# => network :
#  UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): Up(
#     (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): Up(
#     (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up4): Up(
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# => loading pretrain model './pretrainedmodel/MODEL.pth'
# PRAKALP 1:  <class 'collections.OrderedDict'>
# => PRAKALP Pretrained Model :
#  UNet(
#   (inc): DoubleConv(
#     (double_conv): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#     )
#   )
#   (down1): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down2): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down3): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (down4): Down(
#     (maxpool_conv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): DoubleConv(
#         (double_conv): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up1): Up(
#     (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up2): Up(
#     (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up3): Up(
#     (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (up4): Up(
#     (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (conv): DoubleConv(
#       (double_conv): Sequential(
#         (0): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#       )
#     )
#   )
#   (outc): OutConv(
#     (conv): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
#   )
# )
# ----------one epoch begin----------
# remaining ratio of pruning : Norm is 1.000000
# reducing ratio of pruning : Distance is 0.200000
# total remaining ratio is 0.800000
#  accu before is: 0.930 %
# torch.Size([64, 3, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([256, 128, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([512, 256, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([1024, 512, 3, 3])
# torch.Size([1024, 1024, 3, 3])
# torch.Size([1024, 512, 2, 2])
# torch.Size([512, 1024, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([512, 256, 2, 2])
# torch.Size([256, 512, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([256, 128, 2, 2])
# torch.Size([128, 256, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([128, 64, 2, 2])
# torch.Size([64, 128, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([2, 64, 1, 1])
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# mask similar Done
#  accu after is: 0.540 %
# Inside Train :
# Epoch 0/5:   0%|                                        | 0/80 [00:00<?, ?img/s]IMAGE LENGTH : 1
# Epoch 0/5:   1%|▏           | 1/80 [00:04<05:55,  4.50s/img, loss (batch)=0.594]IMAGE LENGTH : 1
# Epoch 0/5:   2%|▎           | 2/80 [00:07<04:50,  3.72s/img, loss (batch)=0.343]IMAGE LENGTH : 1
# Epoch 0/5:   4%|▍           | 3/80 [00:10<04:26,  3.46s/img, loss (batch)=0.424]IMAGE LENGTH : 1
# Epoch 0/5:   5%|▌           | 4/80 [00:13<04:13,  3.34s/img, loss (batch)=0.135]IMAGE LENGTH : 1
# Epoch 0/5:   6%|▊            | 5/80 [00:17<04:05,  3.27s/img, loss (batch)=0.46]IMAGE LENGTH : 1
# Epoch 0/5:   8%|▉           | 6/80 [00:20<03:59,  3.23s/img, loss (batch)=0.679]IMAGE LENGTH : 1
# Epoch 0/5:   9%|█           | 7/80 [00:23<03:54,  3.21s/img, loss (batch)=0.396]IMAGE LENGTH : 1
# Epoch 0/5:  10%|█▏          | 8/80 [00:26<03:49,  3.19s/img, loss (batch)=0.337]IMAGE LENGTH : 1
# Epoch 0/5:  11%|█▎          | 9/80 [00:29<03:45,  3.18s/img, loss (batch)=0.456]IMAGE LENGTH : 1
# Epoch 0/5:  12%|█▍         | 10/80 [00:32<03:42,  3.17s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 0/5:  14%|█▋          | 11/80 [00:36<03:38,  3.17s/img, loss (batch)=0.53]IMAGE LENGTH : 1
# Epoch 0/5:  15%|█▋         | 12/80 [00:39<03:35,  3.16s/img, loss (batch)=0.145]IMAGE LENGTH : 1
# Epoch 0/5:  16%|█▊         | 13/80 [00:42<03:31,  3.16s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 0/5:  18%|█▉         | 14/80 [00:45<03:28,  3.16s/img, loss (batch)=0.136]IMAGE LENGTH : 1
# Epoch 0/5:  19%|██         | 15/80 [00:48<03:25,  3.16s/img, loss (batch)=0.522]IMAGE LENGTH : 1
# Epoch 0/5:  20%|██▏        | 16/80 [00:51<03:22,  3.16s/img, loss (batch)=0.281]IMAGE LENGTH : 1
# Epoch 0/5:  21%|██▎        | 17/80 [00:54<03:18,  3.15s/img, loss (batch)=0.388]IMAGE LENGTH : 1
# Epoch 0/5:  22%|██▍        | 18/80 [00:58<03:15,  3.16s/img, loss (batch)=0.438]IMAGE LENGTH : 1
# Epoch 0/5:  24%|██▌        | 19/80 [01:01<03:12,  3.16s/img, loss (batch)=0.152]IMAGE LENGTH : 1
# Epoch 0/5:  25%|██▊        | 20/80 [01:04<03:09,  3.15s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 0/5:  26%|██▉        | 21/80 [01:07<03:06,  3.15s/img, loss (batch)=0.135]IMAGE LENGTH : 1
# Epoch 0/5:  28%|███        | 22/80 [01:10<03:02,  3.16s/img, loss (batch)=0.143]IMAGE LENGTH : 1
# Epoch 0/5:  29%|███▏       | 23/80 [01:13<02:59,  3.15s/img, loss (batch)=0.369]IMAGE LENGTH : 1
# Epoch 0/5:  30%|███▎       | 24/80 [01:17<02:56,  3.16s/img, loss (batch)=0.164]IMAGE LENGTH : 1
# Epoch 0/5:  31%|███▍       | 25/80 [01:20<02:53,  3.16s/img, loss (batch)=0.174]IMAGE LENGTH : 1
# Epoch 0/5:  32%|███▌       | 26/80 [01:23<02:50,  3.15s/img, loss (batch)=0.335]IMAGE LENGTH : 1
# Epoch 0/5:  34%|████        | 27/80 [01:26<02:47,  3.15s/img, loss (batch)=0.57]IMAGE LENGTH : 1
# Epoch 0/5:  35%|████▏       | 28/80 [01:29<02:44,  3.15s/img, loss (batch)=0.39]IMAGE LENGTH : 1
# Epoch 0/5:  36%|███▉       | 29/80 [01:32<02:40,  3.15s/img, loss (batch)=0.576]IMAGE LENGTH : 1
# Epoch 0/5:  38%|████▌       | 30/80 [01:36<02:37,  3.15s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 0/5:  39%|████▎      | 31/80 [01:39<02:34,  3.15s/img, loss (batch)=0.125]IMAGE LENGTH : 1
# Epoch 0/5:  40%|████▍      | 32/80 [01:42<02:31,  3.15s/img, loss (batch)=0.159]IMAGE LENGTH : 1
# Epoch 0/5:  41%|████▌      | 33/80 [01:45<02:28,  3.15s/img, loss (batch)=0.228]IMAGE LENGTH : 1
# Epoch 0/5:  42%|████▋      | 34/80 [01:48<02:25,  3.15s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 0/5:  44%|████▊      | 35/80 [01:51<02:21,  3.15s/img, loss (batch)=0.354]IMAGE LENGTH : 1
# Epoch 0/5:  45%|████▉      | 36/80 [01:54<02:18,  3.15s/img, loss (batch)=0.255]IMAGE LENGTH : 1
# Epoch 0/5:  46%|█████      | 37/80 [01:58<02:15,  3.15s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 0/5:  48%|█████▏     | 38/80 [02:01<02:12,  3.15s/img, loss (batch)=0.264]IMAGE LENGTH : 1
# Epoch 0/5:  49%|█████▊      | 39/80 [02:04<02:09,  3.15s/img, loss (batch)=0.19]IMAGE LENGTH : 1
# Epoch 0/5:  50%|█████▌     | 40/80 [02:07<02:06,  3.15s/img, loss (batch)=0.171]IMAGE LENGTH : 1
# Epoch 0/5:  51%|█████▋     | 41/80 [02:10<02:03,  3.15s/img, loss (batch)=0.452]IMAGE LENGTH : 1
# Epoch 0/5:  52%|█████▊     | 42/80 [02:13<01:59,  3.15s/img, loss (batch)=0.427]IMAGE LENGTH : 1
# Epoch 0/5:  54%|█████▉     | 43/80 [02:17<01:56,  3.15s/img, loss (batch)=0.295]IMAGE LENGTH : 1
# Epoch 0/5:  55%|██████     | 44/80 [02:20<01:53,  3.15s/img, loss (batch)=0.376]IMAGE LENGTH : 1
# Epoch 0/5:  56%|██████▏    | 45/80 [02:23<01:50,  3.15s/img, loss (batch)=0.316]IMAGE LENGTH : 1
# Epoch 0/5:  57%|██████▎    | 46/80 [02:26<01:47,  3.15s/img, loss (batch)=0.178]IMAGE LENGTH : 1
# Epoch 0/5:  59%|██████▍    | 47/80 [02:29<01:44,  3.15s/img, loss (batch)=0.573]IMAGE LENGTH : 1
# Epoch 0/5:  60%|██████▌    | 48/80 [02:32<01:40,  3.15s/img, loss (batch)=0.433]IMAGE LENGTH : 1
# Epoch 0/5:  61%|██████▋    | 49/80 [02:35<01:37,  3.15s/img, loss (batch)=0.173]IMAGE LENGTH : 1
# Epoch 0/5:  62%|██████▉    | 50/80 [02:39<01:34,  3.15s/img, loss (batch)=0.155]IMAGE LENGTH : 1
# Epoch 0/5:  64%|███████    | 51/80 [02:42<01:31,  3.15s/img, loss (batch)=0.184]IMAGE LENGTH : 1
# Epoch 0/5:  65%|███████▊    | 52/80 [02:45<01:28,  3.15s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 0/5:  66%|███████▎   | 53/80 [02:48<01:25,  3.15s/img, loss (batch)=0.292]IMAGE LENGTH : 1
# Epoch 0/5:  68%|████████    | 54/80 [02:51<01:22,  3.15s/img, loss (batch)=0.15]IMAGE LENGTH : 1
# Epoch 0/5:  69%|████████▎   | 55/80 [02:54<01:18,  3.15s/img, loss (batch)=0.48]IMAGE LENGTH : 1
# Epoch 0/5:  70%|███████▋   | 56/80 [02:58<01:15,  3.15s/img, loss (batch)=0.264]IMAGE LENGTH : 1
# Epoch 0/5:  71%|███████▊   | 57/80 [03:01<01:12,  3.15s/img, loss (batch)=0.209]IMAGE LENGTH : 1
# Epoch 0/5:  72%|███████▉   | 58/80 [03:04<01:09,  3.15s/img, loss (batch)=0.512]IMAGE LENGTH : 1
# Epoch 0/5:  74%|████████   | 59/80 [03:07<01:06,  3.15s/img, loss (batch)=0.143]IMAGE LENGTH : 1
# Epoch 0/5:  75%|████████▎  | 60/80 [03:10<01:03,  3.15s/img, loss (batch)=0.276]IMAGE LENGTH : 1
# Epoch 0/5:  76%|████████▍  | 61/80 [03:13<00:59,  3.15s/img, loss (batch)=0.219]IMAGE LENGTH : 1
# Epoch 0/5:  78%|████████▌  | 62/80 [03:16<00:56,  3.15s/img, loss (batch)=0.411]IMAGE LENGTH : 1
# Epoch 0/5:  79%|████████▋  | 63/80 [03:20<00:53,  3.15s/img, loss (batch)=0.201]IMAGE LENGTH : 1
# Epoch 0/5:  80%|████████▊  | 64/80 [03:23<00:50,  3.15s/img, loss (batch)=0.136]IMAGE LENGTH : 1
# Epoch 0/5:  81%|████████▉  | 65/80 [03:26<00:47,  3.15s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 0/5:  82%|█████████  | 66/80 [03:29<00:44,  3.15s/img, loss (batch)=0.195]IMAGE LENGTH : 1
# Epoch 0/5:  84%|██████████  | 67/80 [03:32<00:40,  3.15s/img, loss (batch)=0.47]IMAGE LENGTH : 1
# Epoch 0/5:  85%|█████████▎ | 68/80 [03:35<00:37,  3.15s/img, loss (batch)=0.274]IMAGE LENGTH : 1
# Epoch 0/5:  86%|█████████▍ | 69/80 [03:39<00:34,  3.15s/img, loss (batch)=0.537]IMAGE LENGTH : 1
# Epoch 0/5:  88%|██████████▌ | 70/80 [03:42<00:31,  3.15s/img, loss (batch)=0.16]IMAGE LENGTH : 1
# Epoch 0/5:  89%|█████████▊ | 71/80 [03:45<00:28,  3.15s/img, loss (batch)=0.364]IMAGE LENGTH : 1
# Epoch 0/5:  90%|█████████▉ | 72/80 [03:48<00:25,  3.15s/img, loss (batch)=0.179]IMAGE LENGTH : 1
# Epoch 0/5:  91%|██████████ | 73/80 [03:51<00:22,  3.15s/img, loss (batch)=0.365]IMAGE LENGTH : 1
# Epoch 0/5:  92%|██████████▏| 74/80 [03:54<00:18,  3.15s/img, loss (batch)=0.369]IMAGE LENGTH : 1
# Epoch 0/5:  94%|██████████▎| 75/80 [03:57<00:15,  3.15s/img, loss (batch)=0.229]IMAGE LENGTH : 1
# Epoch 0/5:  95%|██████████▍| 76/80 [04:01<00:12,  3.15s/img, loss (batch)=0.431]IMAGE LENGTH : 1
# Epoch 0/5:  96%|██████████▌| 77/80 [04:04<00:09,  3.15s/img, loss (batch)=0.353]IMAGE LENGTH : 1
# Epoch 0/5:  98%|██████████▋| 78/80 [04:07<00:06,  3.15s/img, loss (batch)=0.191]IMAGE LENGTH : 1
# Epoch 0/5:  99%|██████████▊| 79/80 [04:10<00:03,  3.15s/img, loss (batch)=0.357]IMAGE LENGTH : 1
# Epoch 0/5: 100%|███████████| 80/80 [04:13<00:00,  3.17s/img, loss (batch)=0.306]
# number of nonzero weight is 1728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 9437184, zero is 0
# number of nonzero weight is 2097152, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 524288, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 131072, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 32768, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 128, zero is 0
# torch.Size([64, 3, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([256, 128, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([512, 256, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([1024, 512, 3, 3])
# torch.Size([1024, 1024, 3, 3])
# torch.Size([1024, 512, 2, 2])
# torch.Size([512, 1024, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([512, 256, 2, 2])
# torch.Size([256, 512, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([256, 128, 2, 2])
# torch.Size([128, 256, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([128, 64, 2, 2])
# torch.Size([64, 128, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([2, 64, 1, 1])
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# mask similar Done
# number of nonzero weight is 1728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 9437184, zero is 0
# number of nonzero weight is 1048576, zero is 1048576
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 262144, zero is 262144
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 65536, zero is 65536
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 16384, zero is 16384
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 128, zero is 0
# Inside Train :
# Epoch 1/5:   0%|                                        | 0/80 [00:00<?, ?img/s]IMAGE LENGTH : 1
# Epoch 1/5:   1%|▏           | 1/80 [00:04<05:36,  4.26s/img, loss (batch)=0.159]IMAGE LENGTH : 1
# Epoch 1/5:   2%|▎           | 2/80 [00:07<04:41,  3.61s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 1/5:   4%|▍           | 3/80 [00:10<04:21,  3.40s/img, loss (batch)=0.522]IMAGE LENGTH : 1
# Epoch 1/5:   5%|▋            | 4/80 [00:13<04:11,  3.30s/img, loss (batch)=0.47]IMAGE LENGTH : 1
# Epoch 1/5:   6%|▊           | 5/80 [00:16<04:03,  3.25s/img, loss (batch)=0.179]IMAGE LENGTH : 1
# Epoch 1/5:   8%|▉           | 6/80 [00:20<03:58,  3.22s/img, loss (batch)=0.281]IMAGE LENGTH : 1
# Epoch 1/5:   9%|█           | 7/80 [00:23<03:53,  3.20s/img, loss (batch)=0.135]IMAGE LENGTH : 1
# Epoch 1/5:  10%|█▏          | 8/80 [00:26<03:49,  3.18s/img, loss (batch)=0.173]IMAGE LENGTH : 1
# Epoch 1/5:  11%|█▎          | 9/80 [00:29<03:45,  3.17s/img, loss (batch)=0.459]IMAGE LENGTH : 1
# Epoch 1/5:  12%|█▍         | 10/80 [00:32<03:41,  3.17s/img, loss (batch)=0.364]IMAGE LENGTH : 1
# Epoch 1/5:  14%|█▌         | 11/80 [00:35<03:38,  3.16s/img, loss (batch)=0.343]IMAGE LENGTH : 1
# Epoch 1/5:  15%|█▊          | 12/80 [00:38<03:34,  3.16s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 1/5:  16%|█▊         | 13/80 [00:42<03:31,  3.16s/img, loss (batch)=0.438]IMAGE LENGTH : 1
# Epoch 1/5:  18%|█▉         | 14/80 [00:45<03:28,  3.16s/img, loss (batch)=0.537]IMAGE LENGTH : 1
# Epoch 1/5:  19%|██         | 15/80 [00:48<03:25,  3.16s/img, loss (batch)=0.316]IMAGE LENGTH : 1
# Epoch 1/5:  20%|██▏        | 16/80 [00:51<03:22,  3.16s/img, loss (batch)=0.576]IMAGE LENGTH : 1
# Epoch 1/5:  21%|██▎        | 17/80 [00:54<03:18,  3.16s/img, loss (batch)=0.411]IMAGE LENGTH : 1
# Epoch 1/5:  22%|██▋         | 18/80 [00:57<03:15,  3.16s/img, loss (batch)=0.48]IMAGE LENGTH : 1
# Epoch 1/5:  24%|██▌        | 19/80 [01:01<03:12,  3.15s/img, loss (batch)=0.155]IMAGE LENGTH : 1
# Epoch 1/5:  25%|██▊        | 20/80 [01:04<03:09,  3.15s/img, loss (batch)=0.201]IMAGE LENGTH : 1
# Epoch 1/5:  26%|██▉        | 21/80 [01:07<03:06,  3.15s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 1/5:  28%|███        | 22/80 [01:10<03:03,  3.16s/img, loss (batch)=0.228]IMAGE LENGTH : 1
# Epoch 1/5:  29%|███▏       | 23/80 [01:13<02:59,  3.15s/img, loss (batch)=0.353]IMAGE LENGTH : 1
# Epoch 1/5:  30%|███▎       | 24/80 [01:16<02:56,  3.15s/img, loss (batch)=0.209]IMAGE LENGTH : 1
# Epoch 1/5:  31%|███▍       | 25/80 [01:19<02:53,  3.15s/img, loss (batch)=0.136]IMAGE LENGTH : 1
# Epoch 1/5:  32%|███▌       | 26/80 [01:23<02:50,  3.15s/img, loss (batch)=0.369]IMAGE LENGTH : 1
# Epoch 1/5:  34%|███▋       | 27/80 [01:26<02:47,  3.15s/img, loss (batch)=0.451]IMAGE LENGTH : 1
# Epoch 1/5:  35%|███▊       | 28/80 [01:29<02:44,  3.15s/img, loss (batch)=0.264]IMAGE LENGTH : 1
# Epoch 1/5:  36%|███▉       | 29/80 [01:32<02:40,  3.15s/img, loss (batch)=0.174]IMAGE LENGTH : 1
# Epoch 1/5:  38%|████▏      | 30/80 [01:35<02:37,  3.15s/img, loss (batch)=0.594]IMAGE LENGTH : 1
# Epoch 1/5:  39%|████▎      | 31/80 [01:38<02:34,  3.15s/img, loss (batch)=0.276]IMAGE LENGTH : 1
# Epoch 1/5:  40%|████▍      | 32/80 [01:42<02:31,  3.15s/img, loss (batch)=0.171]IMAGE LENGTH : 1
# Epoch 1/5:  41%|████▌      | 33/80 [01:45<02:28,  3.15s/img, loss (batch)=0.145]IMAGE LENGTH : 1
# Epoch 1/5:  42%|████▋      | 34/80 [01:48<02:25,  3.15s/img, loss (batch)=0.357]IMAGE LENGTH : 1
# Epoch 1/5:  44%|█████▎      | 35/80 [01:51<02:21,  3.15s/img, loss (batch)=0.19]IMAGE LENGTH : 1
# Epoch 1/5:  45%|████▉      | 36/80 [01:54<02:18,  3.15s/img, loss (batch)=0.369]IMAGE LENGTH : 1
# Epoch 1/5:  46%|█████      | 37/80 [01:57<02:15,  3.16s/img, loss (batch)=0.456]IMAGE LENGTH : 1
# Epoch 1/5:  48%|█████▋      | 38/80 [02:00<02:12,  3.15s/img, loss (batch)=0.53]IMAGE LENGTH : 1
# Epoch 1/5:  49%|█████▎     | 39/80 [02:04<02:09,  3.15s/img, loss (batch)=0.143]IMAGE LENGTH : 1
# Epoch 1/5:  50%|█████▌     | 40/80 [02:07<02:06,  3.15s/img, loss (batch)=0.191]IMAGE LENGTH : 1
# Epoch 1/5:  51%|█████▋     | 41/80 [02:10<02:02,  3.15s/img, loss (batch)=0.164]IMAGE LENGTH : 1
# Epoch 1/5:  52%|█████▊     | 42/80 [02:13<01:59,  3.15s/img, loss (batch)=0.125]IMAGE LENGTH : 1
# Epoch 1/5:  54%|█████▉     | 43/80 [02:16<01:56,  3.15s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 1/5:  55%|██████     | 44/80 [02:19<01:53,  3.15s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 1/5:  56%|██████▏    | 45/80 [02:23<01:50,  3.15s/img, loss (batch)=0.274]IMAGE LENGTH : 1
# Epoch 1/5:  57%|██████▎    | 46/80 [02:26<01:47,  3.15s/img, loss (batch)=0.152]IMAGE LENGTH : 1
# Epoch 1/5:  59%|██████▍    | 47/80 [02:29<01:44,  3.15s/img, loss (batch)=0.354]IMAGE LENGTH : 1
# Epoch 1/5:  60%|██████▌    | 48/80 [02:32<01:40,  3.15s/img, loss (batch)=0.136]IMAGE LENGTH : 1
# Epoch 1/5:  61%|██████▋    | 49/80 [02:35<01:37,  3.15s/img, loss (batch)=0.295]IMAGE LENGTH : 1
# Epoch 1/5:  62%|██████▉    | 50/80 [02:38<01:34,  3.15s/img, loss (batch)=0.679]IMAGE LENGTH : 1
# Epoch 1/5:  64%|███████    | 51/80 [02:41<01:31,  3.15s/img, loss (batch)=0.424]IMAGE LENGTH : 1
# Epoch 1/5:  65%|███████▏   | 52/80 [02:45<01:28,  3.15s/img, loss (batch)=0.135]IMAGE LENGTH : 1
# Epoch 1/5:  66%|███████▎   | 53/80 [02:48<01:25,  3.15s/img, loss (batch)=0.336]IMAGE LENGTH : 1
# Epoch 1/5:  68%|███████▍   | 54/80 [02:51<01:21,  3.15s/img, loss (batch)=0.264]IMAGE LENGTH : 1
# Epoch 1/5:  69%|███████▌   | 55/80 [02:54<01:18,  3.15s/img, loss (batch)=0.178]IMAGE LENGTH : 1
# Epoch 1/5:  70%|████████▍   | 56/80 [02:57<01:15,  3.15s/img, loss (batch)=0.15]IMAGE LENGTH : 1
# Epoch 1/5:  71%|███████▊   | 57/80 [03:00<01:12,  3.15s/img, loss (batch)=0.572]IMAGE LENGTH : 1
# Epoch 1/5:  72%|███████▉   | 58/80 [03:04<01:09,  3.15s/img, loss (batch)=0.195]IMAGE LENGTH : 1
# Epoch 1/5:  74%|████████   | 59/80 [03:07<01:06,  3.15s/img, loss (batch)=0.427]IMAGE LENGTH : 1
# Epoch 1/5:  75%|█████████   | 60/80 [03:10<01:03,  3.15s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 1/5:  76%|████████▍  | 61/80 [03:13<00:59,  3.15s/img, loss (batch)=0.335]IMAGE LENGTH : 1
# Epoch 1/5:  78%|████████▌  | 62/80 [03:16<00:56,  3.15s/img, loss (batch)=0.306]IMAGE LENGTH : 1
# Epoch 1/5:  79%|████████▋  | 63/80 [03:19<00:53,  3.15s/img, loss (batch)=0.292]IMAGE LENGTH : 1
# Epoch 1/5:  80%|████████▊  | 64/80 [03:22<00:50,  3.15s/img, loss (batch)=0.431]IMAGE LENGTH : 1
# Epoch 1/5:  81%|████████▉  | 65/80 [03:26<00:47,  3.15s/img, loss (batch)=0.376]IMAGE LENGTH : 1
# Epoch 1/5:  82%|█████████  | 66/80 [03:29<00:44,  3.15s/img, loss (batch)=0.365]IMAGE LENGTH : 1
# Epoch 1/5:  84%|█████████▏ | 67/80 [03:32<00:41,  3.15s/img, loss (batch)=0.229]IMAGE LENGTH : 1
# Epoch 1/5:  85%|██████████▏ | 68/80 [03:35<00:37,  3.15s/img, loss (batch)=0.57]IMAGE LENGTH : 1
# Epoch 1/5:  86%|█████████▍ | 69/80 [03:38<00:34,  3.16s/img, loss (batch)=0.512]IMAGE LENGTH : 1
# Epoch 1/5:  88%|█████████▋ | 70/80 [03:41<00:31,  3.16s/img, loss (batch)=0.143]IMAGE LENGTH : 1
# Epoch 1/5:  89%|█████████▊ | 71/80 [03:45<00:28,  3.15s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 1/5:  90%|█████████▉ | 72/80 [03:48<00:25,  3.15s/img, loss (batch)=0.219]IMAGE LENGTH : 1
# Epoch 1/5:  91%|██████████ | 73/80 [03:51<00:22,  3.15s/img, loss (batch)=0.396]IMAGE LENGTH : 1
# Epoch 1/5:  92%|███████████ | 74/80 [03:54<00:18,  3.15s/img, loss (batch)=0.16]IMAGE LENGTH : 1
# Epoch 1/5:  94%|███████████▎| 75/80 [03:57<00:15,  3.16s/img, loss (batch)=0.39]IMAGE LENGTH : 1
# Epoch 1/5:  95%|██████████▍| 76/80 [04:00<00:12,  3.15s/img, loss (batch)=0.388]IMAGE LENGTH : 1
# Epoch 1/5:  96%|██████████▌| 77/80 [04:03<00:09,  3.15s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 1/5:  98%|██████████▋| 78/80 [04:07<00:06,  3.15s/img, loss (batch)=0.255]IMAGE LENGTH : 1
# Epoch 1/5:  99%|██████████▊| 79/80 [04:10<00:03,  3.15s/img, loss (batch)=0.433]IMAGE LENGTH : 1
# Epoch 1/5: 100%|███████████| 80/80 [04:13<00:00,  3.17s/img, loss (batch)=0.184]
# number of nonzero weight is 1728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 9437184, zero is 0
# number of nonzero weight is 2097152, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 524288, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 131072, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 32768, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 128, zero is 0
# torch.Size([64, 3, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([256, 128, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([512, 256, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([1024, 512, 3, 3])
# torch.Size([1024, 1024, 3, 3])
# torch.Size([1024, 512, 2, 2])
# torch.Size([512, 1024, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([512, 256, 2, 2])
# torch.Size([256, 512, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([256, 128, 2, 2])
# torch.Size([128, 256, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([128, 64, 2, 2])
# torch.Size([64, 128, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([2, 64, 1, 1])
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# mask similar Done
# number of nonzero weight is 1728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 9437184, zero is 0
# number of nonzero weight is 1048576, zero is 1048576
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 262144, zero is 262144
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 65536, zero is 65536
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 16384, zero is 16384
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 128, zero is 0
# Inside Train :
# Epoch 2/5:   0%|                                        | 0/80 [00:00<?, ?img/s]IMAGE LENGTH : 1
# Epoch 2/5:   1%|▏           | 1/80 [00:04<05:39,  4.29s/img, loss (batch)=0.274]IMAGE LENGTH : 1
# Epoch 2/5:   2%|▎            | 2/80 [00:07<04:42,  3.62s/img, loss (batch)=0.19]IMAGE LENGTH : 1
# Epoch 2/5:   4%|▍            | 3/80 [00:10<04:22,  3.41s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 2/5:   5%|▌           | 4/80 [00:13<04:11,  3.31s/img, loss (batch)=0.357]IMAGE LENGTH : 1
# Epoch 2/5:   6%|▊           | 5/80 [00:16<04:03,  3.25s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 2/5:   8%|▉           | 6/80 [00:20<03:58,  3.22s/img, loss (batch)=0.427]IMAGE LENGTH : 1
# Epoch 2/5:   9%|█           | 7/80 [00:23<03:53,  3.20s/img, loss (batch)=0.229]IMAGE LENGTH : 1
# Epoch 2/5:  10%|█▏          | 8/80 [00:26<03:49,  3.18s/img, loss (batch)=0.376]IMAGE LENGTH : 1
# Epoch 2/5:  11%|█▍           | 9/80 [00:29<03:45,  3.17s/img, loss (batch)=0.16]IMAGE LENGTH : 1
# Epoch 2/5:  12%|█▍         | 10/80 [00:32<03:41,  3.17s/img, loss (batch)=0.433]IMAGE LENGTH : 1
# Epoch 2/5:  14%|█▌         | 11/80 [00:35<03:38,  3.16s/img, loss (batch)=0.201]IMAGE LENGTH : 1
# Epoch 2/5:  15%|█▋         | 12/80 [00:38<03:34,  3.16s/img, loss (batch)=0.184]IMAGE LENGTH : 1
# Epoch 2/5:  16%|█▊         | 13/80 [00:42<03:31,  3.16s/img, loss (batch)=0.219]IMAGE LENGTH : 1
# Epoch 2/5:  18%|█▉         | 14/80 [00:45<03:28,  3.16s/img, loss (batch)=0.163]IMAGE LENGTH : 1
# Epoch 2/5:  19%|██         | 15/80 [00:48<03:25,  3.16s/img, loss (batch)=0.174]IMAGE LENGTH : 1
# Epoch 2/5:  20%|██▏        | 16/80 [00:51<03:21,  3.15s/img, loss (batch)=0.537]IMAGE LENGTH : 1
# Epoch 2/5:  21%|██▎        | 17/80 [00:54<03:18,  3.16s/img, loss (batch)=0.264]IMAGE LENGTH : 1
# Epoch 2/5:  22%|██▍        | 18/80 [00:57<03:15,  3.15s/img, loss (batch)=0.179]IMAGE LENGTH : 1
# Epoch 2/5:  24%|██▌        | 19/80 [01:01<03:12,  3.15s/img, loss (batch)=0.678]IMAGE LENGTH : 1
# Epoch 2/5:  25%|██▊        | 20/80 [01:04<03:09,  3.15s/img, loss (batch)=0.295]IMAGE LENGTH : 1
# Epoch 2/5:  26%|██▉        | 21/80 [01:07<03:06,  3.15s/img, loss (batch)=0.336]IMAGE LENGTH : 1
# Epoch 2/5:  28%|███        | 22/80 [01:10<03:02,  3.15s/img, loss (batch)=0.195]IMAGE LENGTH : 1
# Epoch 2/5:  29%|███▍        | 23/80 [01:13<02:59,  3.15s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 2/5:  30%|███▎       | 24/80 [01:16<02:56,  3.16s/img, loss (batch)=0.343]IMAGE LENGTH : 1
# Epoch 2/5:  31%|███▍       | 25/80 [01:19<02:53,  3.15s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 2/5:  32%|███▉        | 26/80 [01:23<02:50,  3.15s/img, loss (batch)=0.57]IMAGE LENGTH : 1
# Epoch 2/5:  34%|███▋       | 27/80 [01:26<02:47,  3.15s/img, loss (batch)=0.152]IMAGE LENGTH : 1
# Epoch 2/5:  35%|███▊       | 28/80 [01:29<02:44,  3.15s/img, loss (batch)=0.364]IMAGE LENGTH : 1
# Epoch 2/5:  36%|███▉       | 29/80 [01:32<02:40,  3.15s/img, loss (batch)=0.335]IMAGE LENGTH : 1
# Epoch 2/5:  38%|████▏      | 30/80 [01:35<02:37,  3.15s/img, loss (batch)=0.576]IMAGE LENGTH : 1
# Epoch 2/5:  39%|████▋       | 31/80 [01:38<02:34,  3.15s/img, loss (batch)=0.47]IMAGE LENGTH : 1
# Epoch 2/5:  40%|████▍      | 32/80 [01:42<02:31,  3.15s/img, loss (batch)=0.369]IMAGE LENGTH : 1
# Epoch 2/5:  41%|████▌      | 33/80 [01:45<02:28,  3.15s/img, loss (batch)=0.143]IMAGE LENGTH : 1
# Epoch 2/5:  42%|████▋      | 34/80 [01:48<02:25,  3.15s/img, loss (batch)=0.456]IMAGE LENGTH : 1
# Epoch 2/5:  44%|████▊      | 35/80 [01:51<02:21,  3.15s/img, loss (batch)=0.424]IMAGE LENGTH : 1
# Epoch 2/5:  45%|████▉      | 36/80 [01:54<02:18,  3.15s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 2/5:  46%|█████      | 37/80 [01:57<02:15,  3.15s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 2/5:  48%|█████▏     | 38/80 [02:00<02:12,  3.15s/img, loss (batch)=0.316]IMAGE LENGTH : 1
# Epoch 2/5:  49%|█████▎     | 39/80 [02:04<02:09,  3.15s/img, loss (batch)=0.292]IMAGE LENGTH : 1
# Epoch 2/5:  50%|██████      | 40/80 [02:07<02:06,  3.15s/img, loss (batch)=0.48]IMAGE LENGTH : 1
# Epoch 2/5:  51%|█████▋     | 41/80 [02:10<02:03,  3.15s/img, loss (batch)=0.209]IMAGE LENGTH : 1
# Epoch 2/5:  52%|█████▊     | 42/80 [02:13<01:59,  3.15s/img, loss (batch)=0.136]IMAGE LENGTH : 1
# Epoch 2/5:  54%|█████▉     | 43/80 [02:16<01:56,  3.15s/img, loss (batch)=0.306]IMAGE LENGTH : 1
# Epoch 2/5:  55%|██████     | 44/80 [02:19<01:53,  3.15s/img, loss (batch)=0.125]IMAGE LENGTH : 1
# Epoch 2/5:  56%|██████▏    | 45/80 [02:23<01:50,  3.15s/img, loss (batch)=0.396]IMAGE LENGTH : 1
# Epoch 2/5:  57%|██████▎    | 46/80 [02:26<01:47,  3.15s/img, loss (batch)=0.264]IMAGE LENGTH : 1
# Epoch 2/5:  59%|███████     | 47/80 [02:29<01:44,  3.15s/img, loss (batch)=0.15]IMAGE LENGTH : 1
# Epoch 2/5:  60%|██████▌    | 48/80 [02:32<01:40,  3.15s/img, loss (batch)=0.572]IMAGE LENGTH : 1
# Epoch 2/5:  61%|██████▋    | 49/80 [02:35<01:37,  3.15s/img, loss (batch)=0.143]IMAGE LENGTH : 1
# Epoch 2/5:  62%|██████▉    | 50/80 [02:38<01:34,  3.15s/img, loss (batch)=0.136]IMAGE LENGTH : 1
# Epoch 2/5:  64%|███████    | 51/80 [02:41<01:31,  3.15s/img, loss (batch)=0.171]IMAGE LENGTH : 1
# Epoch 2/5:  65%|███████▏   | 52/80 [02:45<01:28,  3.15s/img, loss (batch)=0.512]IMAGE LENGTH : 1
# Epoch 2/5:  66%|███████▎   | 53/80 [02:48<01:25,  3.15s/img, loss (batch)=0.281]IMAGE LENGTH : 1
# Epoch 2/5:  68%|███████▍   | 54/80 [02:51<01:21,  3.15s/img, loss (batch)=0.411]IMAGE LENGTH : 1
# Epoch 2/5:  69%|████████▎   | 55/80 [02:54<01:18,  3.15s/img, loss (batch)=0.39]IMAGE LENGTH : 1
# Epoch 2/5:  70%|███████▋   | 56/80 [02:57<01:15,  3.15s/img, loss (batch)=0.438]IMAGE LENGTH : 1
# Epoch 2/5:  71%|███████▊   | 57/80 [03:00<01:12,  3.15s/img, loss (batch)=0.354]IMAGE LENGTH : 1
# Epoch 2/5:  72%|███████▉   | 58/80 [03:04<01:09,  3.15s/img, loss (batch)=0.255]IMAGE LENGTH : 1
# Epoch 2/5:  74%|████████   | 59/80 [03:07<01:06,  3.15s/img, loss (batch)=0.365]IMAGE LENGTH : 1
# Epoch 2/5:  75%|████████▎  | 60/80 [03:10<01:03,  3.15s/img, loss (batch)=0.178]IMAGE LENGTH : 1
# Epoch 2/5:  76%|████████▍  | 61/80 [03:13<00:59,  3.15s/img, loss (batch)=0.145]IMAGE LENGTH : 1
# Epoch 2/5:  78%|████████▌  | 62/80 [03:16<00:56,  3.15s/img, loss (batch)=0.459]IMAGE LENGTH : 1
# Epoch 2/5:  79%|████████▋  | 63/80 [03:19<00:53,  3.15s/img, loss (batch)=0.159]IMAGE LENGTH : 1
# Epoch 2/5:  80%|█████████▌  | 64/80 [03:22<00:50,  3.15s/img, loss (batch)=0.53]IMAGE LENGTH : 1
# Epoch 2/5:  81%|████████▉  | 65/80 [03:26<00:47,  3.15s/img, loss (batch)=0.594]IMAGE LENGTH : 1
# Epoch 2/5:  82%|█████████  | 66/80 [03:29<00:44,  3.15s/img, loss (batch)=0.135]IMAGE LENGTH : 1
# Epoch 2/5:  84%|█████████▏ | 67/80 [03:32<00:40,  3.15s/img, loss (batch)=0.135]IMAGE LENGTH : 1
# Epoch 2/5:  85%|█████████▎ | 68/80 [03:35<00:37,  3.15s/img, loss (batch)=0.431]IMAGE LENGTH : 1
# Epoch 2/5:  86%|█████████▍ | 69/80 [03:38<00:34,  3.15s/img, loss (batch)=0.173]IMAGE LENGTH : 1
# Epoch 2/5:  88%|█████████▋ | 70/80 [03:41<00:31,  3.15s/img, loss (batch)=0.228]IMAGE LENGTH : 1
# Epoch 2/5:  89%|█████████▊ | 71/80 [03:45<00:28,  3.15s/img, loss (batch)=0.353]IMAGE LENGTH : 1
# Epoch 2/5:  90%|█████████▉ | 72/80 [03:48<00:25,  3.15s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 2/5:  91%|██████████ | 73/80 [03:51<00:22,  3.15s/img, loss (batch)=0.369]IMAGE LENGTH : 1
# Epoch 2/5:  92%|██████████▏| 74/80 [03:54<00:18,  3.16s/img, loss (batch)=0.388]IMAGE LENGTH : 1
# Epoch 2/5:  94%|██████████▎| 75/80 [03:57<00:15,  3.16s/img, loss (batch)=0.276]IMAGE LENGTH : 1
# Epoch 2/5:  95%|██████████▍| 76/80 [04:00<00:12,  3.15s/img, loss (batch)=0.521]IMAGE LENGTH : 1
# Epoch 2/5:  96%|██████████▌| 77/80 [04:03<00:09,  3.15s/img, loss (batch)=0.155]IMAGE LENGTH : 1
# Epoch 2/5:  98%|██████████▋| 78/80 [04:07<00:06,  3.15s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 2/5:  99%|██████████▊| 79/80 [04:10<00:03,  3.15s/img, loss (batch)=0.451]IMAGE LENGTH : 1
# Epoch 2/5: 100%|███████████| 80/80 [04:13<00:00,  3.17s/img, loss (batch)=0.191]
# number of nonzero weight is 1728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 9437184, zero is 0
# number of nonzero weight is 2097152, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 524288, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 131072, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 32768, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 128, zero is 0
# torch.Size([64, 3, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([256, 128, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([512, 256, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([1024, 512, 3, 3])
# torch.Size([1024, 1024, 3, 3])
# torch.Size([1024, 512, 2, 2])
# torch.Size([512, 1024, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([512, 256, 2, 2])
# torch.Size([256, 512, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([256, 128, 2, 2])
# torch.Size([128, 256, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([128, 64, 2, 2])
# torch.Size([64, 128, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([2, 64, 1, 1])
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# mask similar Done
# number of nonzero weight is 1728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 9437184, zero is 0
# number of nonzero weight is 1048576, zero is 1048576
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 262144, zero is 262144
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 65536, zero is 65536
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 147456, zero is 0
# ...
# Epoch 5/5:  29%|███▏       | 23/80 [01:13<02:59,  3.15s/img, loss (batch)=0.364]IMAGE LENGTH : 1
# Epoch 5/5:  30%|███▎       | 24/80 [01:16<02:56,  3.15s/img, loss (batch)=0.295]IMAGE LENGTH : 1
# Epoch 5/5:  31%|███▍       | 25/80 [01:20<02:53,  3.15s/img, loss (batch)=0.437]IMAGE LENGTH : 1
# Epoch 5/5:  32%|███▌       | 26/80 [01:23<02:50,  3.15s/img, loss (batch)=0.184]IMAGE LENGTH : 1
# Epoch 5/5:  34%|███▋       | 27/80 [01:26<02:47,  3.15s/img, loss (batch)=0.276]IMAGE LENGTH : 1
# Epoch 5/5:  35%|███▊       | 28/80 [01:29<02:43,  3.15s/img, loss (batch)=0.136]IMAGE LENGTH : 1
# Epoch 5/5:  36%|███▉       | 29/80 [01:32<02:40,  3.15s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 5/5:  38%|████▏      | 30/80 [01:35<02:37,  3.15s/img, loss (batch)=0.479]IMAGE LENGTH : 1
# Epoch 5/5:  39%|████▋       | 31/80 [01:39<02:34,  3.15s/img, loss (batch)=0.16]IMAGE LENGTH : 1
# Epoch 5/5:  40%|████▍      | 32/80 [01:42<02:31,  3.15s/img, loss (batch)=0.529]IMAGE LENGTH : 1
# Epoch 5/5:  41%|████▌      | 33/80 [01:45<02:28,  3.15s/img, loss (batch)=0.678]IMAGE LENGTH : 1
# Epoch 5/5:  42%|████▋      | 34/80 [01:48<02:25,  3.15s/img, loss (batch)=0.387]IMAGE LENGTH : 1
# Epoch 5/5:  44%|████▊      | 35/80 [01:51<02:21,  3.15s/img, loss (batch)=0.264]IMAGE LENGTH : 1
# Epoch 5/5:  45%|████▉      | 36/80 [01:54<02:18,  3.15s/img, loss (batch)=0.521]IMAGE LENGTH : 1
# Epoch 5/5:  46%|█████      | 37/80 [01:57<02:15,  3.15s/img, loss (batch)=0.125]IMAGE LENGTH : 1
# Epoch 5/5:  48%|█████▏     | 38/80 [02:01<02:12,  3.16s/img, loss (batch)=0.281]IMAGE LENGTH : 1
# Epoch 5/5:  49%|█████▊      | 39/80 [02:04<02:09,  3.16s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 5/5:  50%|█████▌     | 40/80 [02:07<02:06,  3.15s/img, loss (batch)=0.219]IMAGE LENGTH : 1
# Epoch 5/5:  51%|█████▋     | 41/80 [02:10<02:03,  3.16s/img, loss (batch)=0.376]IMAGE LENGTH : 1
# Epoch 5/5:  52%|█████▊     | 42/80 [02:13<01:59,  3.15s/img, loss (batch)=0.459]IMAGE LENGTH : 1
# Epoch 5/5:  54%|█████▉     | 43/80 [02:16<01:56,  3.15s/img, loss (batch)=0.195]IMAGE LENGTH : 1
# Epoch 5/5:  55%|██████     | 44/80 [02:20<01:53,  3.15s/img, loss (batch)=0.142]IMAGE LENGTH : 1
# Epoch 5/5:  56%|██████▊     | 45/80 [02:23<01:50,  3.15s/img, loss (batch)=0.15]IMAGE LENGTH : 1
# Epoch 5/5:  57%|██████▎    | 46/80 [02:26<01:47,  3.15s/img, loss (batch)=0.264]IMAGE LENGTH : 1
# Epoch 5/5:  59%|██████▍    | 47/80 [02:29<01:44,  3.15s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 5/5:  60%|██████▌    | 48/80 [02:32<01:40,  3.15s/img, loss (batch)=0.424]IMAGE LENGTH : 1
# Epoch 5/5:  61%|██████▋    | 49/80 [02:35<01:37,  3.16s/img, loss (batch)=0.368]IMAGE LENGTH : 1
# Epoch 5/5:  62%|██████▉    | 50/80 [02:38<01:34,  3.15s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 5/5:  64%|███████▋    | 51/80 [02:42<01:31,  3.15s/img, loss (batch)=0.43]IMAGE LENGTH : 1
# Epoch 5/5:  65%|███████▊    | 52/80 [02:45<01:28,  3.15s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 5/5:  66%|███████▎   | 53/80 [02:48<01:25,  3.15s/img, loss (batch)=0.354]IMAGE LENGTH : 1
# Epoch 5/5:  68%|███████▍   | 54/80 [02:51<01:22,  3.15s/img, loss (batch)=0.152]IMAGE LENGTH : 1
# Epoch 5/5:  69%|███████▌   | 55/80 [02:54<01:18,  3.16s/img, loss (batch)=0.469]IMAGE LENGTH : 1
# Epoch 5/5:  70%|███████▋   | 56/80 [02:57<01:15,  3.15s/img, loss (batch)=0.228]IMAGE LENGTH : 1
# Epoch 5/5:  71%|████████▌   | 57/80 [03:01<01:12,  3.16s/img, loss (batch)=0.19]IMAGE LENGTH : 1
# Epoch 5/5:  72%|███████▉   | 58/80 [03:04<01:09,  3.15s/img, loss (batch)=0.369]IMAGE LENGTH : 1
# Epoch 5/5:  74%|████████   | 59/80 [03:07<01:06,  3.15s/img, loss (batch)=0.171]IMAGE LENGTH : 1
# Epoch 5/5:  75%|████████▎  | 60/80 [03:10<01:03,  3.15s/img, loss (batch)=0.353]IMAGE LENGTH : 1
# Epoch 5/5:  76%|████████▍  | 61/80 [03:13<00:59,  3.15s/img, loss (batch)=0.229]IMAGE LENGTH : 1
# Epoch 5/5:  78%|████████▌  | 62/80 [03:16<00:56,  3.15s/img, loss (batch)=0.201]IMAGE LENGTH : 1
# Epoch 5/5:  79%|████████▋  | 63/80 [03:19<00:53,  3.15s/img, loss (batch)=0.274]IMAGE LENGTH : 1
# Epoch 5/5:  80%|████████▊  | 64/80 [03:23<00:50,  3.15s/img, loss (batch)=0.335]IMAGE LENGTH : 1
# Epoch 5/5:  81%|████████▉  | 65/80 [03:26<00:47,  3.15s/img, loss (batch)=0.512]IMAGE LENGTH : 1
# Epoch 5/5:  82%|█████████  | 66/80 [03:29<00:44,  3.15s/img, loss (batch)=0.572]IMAGE LENGTH : 1
# Epoch 5/5:  84%|█████████▏ | 67/80 [03:32<00:41,  3.15s/img, loss (batch)=0.455]IMAGE LENGTH : 1
# Epoch 5/5:  85%|█████████▎ | 68/80 [03:35<00:37,  3.15s/img, loss (batch)=0.316]IMAGE LENGTH : 1
# Epoch 5/5:  86%|█████████▍ | 69/80 [03:38<00:34,  3.15s/img, loss (batch)=0.178]IMAGE LENGTH : 1
# Epoch 5/5:  88%|██████████▌ | 70/80 [03:42<00:31,  3.15s/img, loss (batch)=0.19]IMAGE LENGTH : 1
# Epoch 5/5:  89%|█████████▊ | 71/80 [03:45<00:28,  3.15s/img, loss (batch)=0.292]IMAGE LENGTH : 1
# Epoch 5/5:  90%|█████████▉ | 72/80 [03:48<00:25,  3.15s/img, loss (batch)=0.145]IMAGE LENGTH : 1
# Epoch 5/5:  91%|██████████ | 73/80 [03:51<00:22,  3.16s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 5/5:  92%|██████████▏| 74/80 [03:54<00:18,  3.16s/img, loss (batch)=0.143]IMAGE LENGTH : 1
# Epoch 5/5:  94%|██████████▎| 75/80 [03:57<00:15,  3.15s/img, loss (batch)=0.135]IMAGE LENGTH : 1
# Epoch 5/5:  95%|██████████▍| 76/80 [04:01<00:12,  3.15s/img, loss (batch)=0.396]IMAGE LENGTH : 1
# Epoch 5/5:  96%|██████████▌| 77/80 [04:04<00:09,  3.15s/img, loss (batch)=0.569]IMAGE LENGTH : 1
# Epoch 5/5:  98%|██████████▋| 78/80 [04:07<00:06,  3.15s/img, loss (batch)=0.178]IMAGE LENGTH : 1
# Epoch 5/5:  99%|██████████▊| 79/80 [04:10<00:03,  3.15s/img, loss (batch)=0.343]IMAGE LENGTH : 1
# Epoch 5/5: 100%|███████████| 80/80 [04:13<00:00,  3.17s/img, loss (batch)=0.173]
# number of nonzero weight is 1728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 9437184, zero is 0
# number of nonzero weight is 2097152, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 524288, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 131072, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 32768, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 128, zero is 0
# torch.Size([64, 3, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([128, 64, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([256, 128, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([512, 256, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([1024, 512, 3, 3])
# torch.Size([1024, 1024, 3, 3])
# torch.Size([1024, 512, 2, 2])
# torch.Size([512, 1024, 3, 3])
# torch.Size([512, 512, 3, 3])
# torch.Size([512, 256, 2, 2])
# torch.Size([256, 512, 3, 3])
# torch.Size([256, 256, 3, 3])
# torch.Size([256, 128, 2, 2])
# torch.Size([128, 256, 3, 3])
# torch.Size([128, 128, 3, 3])
# torch.Size([128, 64, 2, 2])
# torch.Size([64, 128, 3, 3])
# torch.Size([64, 64, 3, 3])
# torch.Size([2, 64, 1, 1])
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# filter codebook done
# mask Ready
# mask Done
# mask similar Done
# number of nonzero weight is 1728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 9437184, zero is 0
# number of nonzero weight is 1048576, zero is 1048576
# number of nonzero weight is 4718592, zero is 0
# number of nonzero weight is 2359296, zero is 0
# number of nonzero weight is 262144, zero is 262144
# number of nonzero weight is 1179648, zero is 0
# number of nonzero weight is 589824, zero is 0
# number of nonzero weight is 65536, zero is 65536
# number of nonzero weight is 294912, zero is 0
# number of nonzero weight is 147456, zero is 0
# number of nonzero weight is 16384, zero is 16384
# number of nonzero weight is 73728, zero is 0
# number of nonzero weight is 36864, zero is 0
# number of nonzero weight is 128, zero is 0
# Inside Train :
# Epoch 6/5:   0%|                                        | 0/80 [00:00<?, ?img/s]IMAGE LENGTH : 1
# Epoch 6/5:   1%|▏           | 1/80 [00:04<05:36,  4.27s/img, loss (batch)=0.678]IMAGE LENGTH : 1
# Epoch 6/5:   2%|▎           | 2/80 [00:07<04:41,  3.61s/img, loss (batch)=0.143]IMAGE LENGTH : 1
# Epoch 6/5:   4%|▍           | 3/80 [00:10<04:21,  3.40s/img, loss (batch)=0.178]IMAGE LENGTH : 1
# Epoch 6/5:   5%|▌           | 4/80 [00:13<04:11,  3.30s/img, loss (batch)=0.387]IMAGE LENGTH : 1
# Epoch 6/5:   6%|▊           | 5/80 [00:16<04:03,  3.25s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 6/5:   8%|▉           | 6/80 [00:20<03:58,  3.22s/img, loss (batch)=0.178]IMAGE LENGTH : 1
# Epoch 6/5:   9%|█           | 7/80 [00:23<03:53,  3.20s/img, loss (batch)=0.228]IMAGE LENGTH : 1
# Epoch 6/5:  10%|█▏          | 8/80 [00:26<03:49,  3.18s/img, loss (batch)=0.335]IMAGE LENGTH : 1
# Epoch 6/5:  11%|█▎          | 9/80 [00:29<03:45,  3.17s/img, loss (batch)=0.171]IMAGE LENGTH : 1
# Epoch 6/5:  12%|█▍         | 10/80 [00:32<03:41,  3.17s/img, loss (batch)=0.432]IMAGE LENGTH : 1
# Epoch 6/5:  14%|█▋          | 11/80 [00:35<03:38,  3.16s/img, loss (batch)=0.23]IMAGE LENGTH : 1
# Epoch 6/5:  15%|█▋         | 12/80 [00:38<03:34,  3.16s/img, loss (batch)=0.219]IMAGE LENGTH : 1
# Epoch 6/5:  16%|█▊         | 13/80 [00:42<03:31,  3.16s/img, loss (batch)=0.195]IMAGE LENGTH : 1
# Epoch 6/5:  18%|█▉         | 14/80 [00:45<03:28,  3.16s/img, loss (batch)=0.459]IMAGE LENGTH : 1
# Epoch 6/5:  19%|██         | 15/80 [00:48<03:25,  3.16s/img, loss (batch)=0.469]IMAGE LENGTH : 1
# Epoch 6/5:  20%|██▏        | 16/80 [00:51<03:22,  3.16s/img, loss (batch)=0.173]IMAGE LENGTH : 1
# Epoch 6/5:  21%|██▌         | 17/80 [00:54<03:18,  3.16s/img, loss (batch)=0.19]IMAGE LENGTH : 1
# Epoch 6/5:  22%|██▍        | 18/80 [00:57<03:15,  3.16s/img, loss (batch)=0.396]IMAGE LENGTH : 1
# Epoch 6/5:  24%|██▌        | 19/80 [01:01<03:12,  3.15s/img, loss (batch)=0.594]IMAGE LENGTH : 1
# Epoch 6/5:  25%|██▊        | 20/80 [01:04<03:09,  3.15s/img, loss (batch)=0.437]IMAGE LENGTH : 1
# Epoch 6/5:  26%|██▉        | 21/80 [01:07<03:06,  3.15s/img, loss (batch)=0.134]IMAGE LENGTH : 1
# Epoch 6/5:  28%|███        | 22/80 [01:10<03:02,  3.15s/img, loss (batch)=0.263]IMAGE LENGTH : 1
# Epoch 6/5:  29%|███▏       | 23/80 [01:13<02:59,  3.15s/img, loss (batch)=0.411]IMAGE LENGTH : 1
# Epoch 6/5:  30%|███▎       | 24/80 [01:16<02:56,  3.15s/img, loss (batch)=0.316]IMAGE LENGTH : 1
# Epoch 6/5:  31%|███▊        | 25/80 [01:19<02:53,  3.15s/img, loss (batch)=0.15]IMAGE LENGTH : 1
# Epoch 6/5:  32%|███▌       | 26/80 [01:23<02:50,  3.15s/img, loss (batch)=0.201]IMAGE LENGTH : 1
# Epoch 6/5:  34%|███▋       | 27/80 [01:26<02:47,  3.15s/img, loss (batch)=0.536]IMAGE LENGTH : 1
# Epoch 6/5:  35%|███▊       | 28/80 [01:29<02:43,  3.15s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 6/5:  36%|███▉       | 29/80 [01:32<02:40,  3.15s/img, loss (batch)=0.142]IMAGE LENGTH : 1
# Epoch 6/5:  38%|████▏      | 30/80 [01:35<02:37,  3.15s/img, loss (batch)=0.569]IMAGE LENGTH : 1
# Epoch 6/5:  39%|████▎      | 31/80 [01:38<02:34,  3.15s/img, loss (batch)=0.174]IMAGE LENGTH : 1
# Epoch 6/5:  40%|████▍      | 32/80 [01:42<02:31,  3.15s/img, loss (batch)=0.294]IMAGE LENGTH : 1
# Epoch 6/5:  41%|████▉       | 33/80 [01:45<02:28,  3.16s/img, loss (batch)=0.16]IMAGE LENGTH : 1
# Epoch 6/5:  42%|████▋      | 34/80 [01:48<02:25,  3.16s/img, loss (batch)=0.136]IMAGE LENGTH : 1
# Epoch 6/5:  44%|████▊      | 35/80 [01:51<02:21,  3.16s/img, loss (batch)=0.576]IMAGE LENGTH : 1
# Epoch 6/5:  45%|████▉      | 36/80 [01:54<02:18,  3.16s/img, loss (batch)=0.363]IMAGE LENGTH : 1
# Epoch 6/5:  46%|█████▌      | 37/80 [01:57<02:15,  3.15s/img, loss (batch)=0.19]IMAGE LENGTH : 1
# Epoch 6/5:  48%|█████▏     | 38/80 [02:00<02:12,  3.15s/img, loss (batch)=0.281]IMAGE LENGTH : 1
# Epoch 6/5:  49%|█████▎     | 39/80 [02:04<02:09,  3.16s/img, loss (batch)=0.423]IMAGE LENGTH : 1
# Epoch 6/5:  50%|█████▌     | 40/80 [02:07<02:06,  3.16s/img, loss (batch)=0.354]IMAGE LENGTH : 1
# Epoch 6/5:  51%|█████▋     | 41/80 [02:10<02:03,  3.16s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 6/5:  52%|█████▊     | 42/80 [02:13<01:59,  3.16s/img, loss (batch)=0.229]IMAGE LENGTH : 1
# Epoch 6/5:  54%|█████▉     | 43/80 [02:16<01:56,  3.15s/img, loss (batch)=0.529]IMAGE LENGTH : 1
# Epoch 6/5:  55%|██████     | 44/80 [02:19<01:53,  3.15s/img, loss (batch)=0.364]IMAGE LENGTH : 1
# Epoch 6/5:  56%|██████▏    | 45/80 [02:23<01:50,  3.15s/img, loss (batch)=0.135]IMAGE LENGTH : 1
# Epoch 6/5:  57%|██████▎    | 46/80 [02:26<01:47,  3.15s/img, loss (batch)=0.479]IMAGE LENGTH : 1
# Epoch 6/5:  59%|██████▍    | 47/80 [02:29<01:44,  3.15s/img, loss (batch)=0.455]IMAGE LENGTH : 1
# Epoch 6/5:  60%|██████▌    | 48/80 [02:32<01:40,  3.15s/img, loss (batch)=0.145]IMAGE LENGTH : 1
# Epoch 6/5:  61%|██████▋    | 49/80 [02:35<01:37,  3.15s/img, loss (batch)=0.389]IMAGE LENGTH : 1
# Epoch 6/5:  62%|██████▉    | 50/80 [02:38<01:34,  3.15s/img, loss (batch)=0.255]IMAGE LENGTH : 1
# Epoch 6/5:  64%|███████    | 51/80 [02:41<01:31,  3.15s/img, loss (batch)=0.368]IMAGE LENGTH : 1
# Epoch 6/5:  65%|███████▏   | 52/80 [02:45<01:28,  3.15s/img, loss (batch)=0.169]IMAGE LENGTH : 1
# Epoch 6/5:  66%|███████▎   | 53/80 [02:48<01:25,  3.15s/img, loss (batch)=0.357]IMAGE LENGTH : 1
# Epoch 6/5:  68%|███████▍   | 54/80 [02:51<01:21,  3.15s/img, loss (batch)=0.192]IMAGE LENGTH : 1
# Epoch 6/5:  69%|███████▌   | 55/80 [02:54<01:18,  3.15s/img, loss (batch)=0.163]IMAGE LENGTH : 1
# Epoch 6/5:  70%|████████▍   | 56/80 [02:57<01:15,  3.15s/img, loss (batch)=0.43]IMAGE LENGTH : 1
# Epoch 6/5:  71%|███████▊   | 57/80 [03:00<01:12,  3.15s/img, loss (batch)=0.188]IMAGE LENGTH : 1
# Epoch 6/5:  72%|███████▉   | 58/80 [03:04<01:09,  3.15s/img, loss (batch)=0.511]IMAGE LENGTH : 1
# Epoch 6/5:  74%|████████   | 59/80 [03:07<01:06,  3.15s/img, loss (batch)=0.427]IMAGE LENGTH : 1
# Epoch 6/5:  75%|████████▎  | 60/80 [03:10<01:03,  3.15s/img, loss (batch)=0.276]IMAGE LENGTH : 1
# Epoch 6/5:  76%|████████▍  | 61/80 [03:13<00:59,  3.15s/img, loss (batch)=0.451]IMAGE LENGTH : 1
# Epoch 6/5:  78%|████████▌  | 62/80 [03:16<00:56,  3.15s/img, loss (batch)=0.155]IMAGE LENGTH : 1
# Epoch 6/5:  79%|████████▋  | 63/80 [03:19<00:53,  3.15s/img, loss (batch)=0.376]IMAGE LENGTH : 1
# Epoch 6/5:  80%|████████▊  | 64/80 [03:22<00:50,  3.15s/img, loss (batch)=0.291]IMAGE LENGTH : 1
# Epoch 6/5:  81%|████████▉  | 65/80 [03:26<00:47,  3.15s/img, loss (batch)=0.159]IMAGE LENGTH : 1
# Epoch 6/5:  82%|█████████  | 66/80 [03:29<00:44,  3.15s/img, loss (batch)=0.152]IMAGE LENGTH : 1
# Epoch 6/5:  84%|█████████▏ | 67/80 [03:32<00:40,  3.15s/img, loss (batch)=0.342]IMAGE LENGTH : 1
# Epoch 6/5:  85%|█████████▎ | 68/80 [03:35<00:37,  3.15s/img, loss (batch)=0.353]IMAGE LENGTH : 1
# Epoch 6/5:  86%|█████████▍ | 69/80 [03:38<00:34,  3.15s/img, loss (batch)=0.521]IMAGE LENGTH : 1
# Epoch 6/5:  88%|█████████▋ | 70/80 [03:41<00:31,  3.15s/img, loss (batch)=0.274]IMAGE LENGTH : 1

# %%
import torch
import sys
sys.path.append("./fpgmdata/testing")
import models

unpruned_model = models.__dict__['UNet'](n_channels=3, n_classes=2)

checkpoint = torch.load("./pretrainedmodel/MODEL.pth", map_location=device)
mask_values = checkpoint.pop('mask_values', [0, 1])
unpruned_model.load_state_dict(checkpoint)

# unpruned_model.load_state_dict(checkpoint['state_dict'])
unpruned_model.to(device)

total = 0
print('Trainable parameters:')

for n, module in unpruned_model.named_modules():
    if isinstance(module, torch.nn.Conv2d):
        for name, param in module.named_parameters():
            if param.requires_grad:
                print(name, '\t', param.numel())
                total += param.numel()
print()
print('Total', '\t', total)
# Out:
# Trainable parameters:
# weight 	 1728
# weight 	 36864
# weight 	 73728
# weight 	 147456
# weight 	 294912
# weight 	 589824
# weight 	 1179648
# weight 	 2359296
# weight 	 4718592
# weight 	 9437184
# weight 	 4718592
# weight 	 2359296
# weight 	 1179648
# weight 	 589824
# weight 	 294912
# weight 	 147456
# weight 	 73728
# weight 	 36864
# weight 	 128
# bias 	 2
#
# Total 	 28239682

# %%
cfg = []
for layer in unpruned_model.modules():
    if isinstance(layer, nn.Conv2d):
        cfg.append(layer.out_channels)
    elif isinstance(layer, nn.MaxPool2d):
        cfg.append('M')
    elif isinstance(layer, nn.ConvTranspose2d):
        cfg.append(layer.out_channels) 
    elif isinstance(layer, nn.Linear):
        cfg.append(layer.out_features)

print("Model Configuration (cfg):", cfg)
# Out:
# Model Configuration (cfg): [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 1024, 1024, 512, 512, 512, 256, 256, 256, 128, 128, 128, 64, 64, 64, 2]

# %% [markdown]
# # General function to test a model

# %%
import numpy as np
import torch.nn.functional as F
import sys
sys.path.append("./fpgmdata/testing")
from dice_score import multiclass_dice_coeff, dice_coeff, dice_loss

def test_model(model):
    model.eval()
    # starter, ender = torch.cuda.Event(enable_timing=True), torch.cuda.Event(enable_timing=True)
    # timings = []
    dice_score1 = 0

    #GPU-WARM-UP
    # i=0
    # for data in testloader:
    #     if(i>20):
    #         break
    #     # images, labels = data
    #     # images = images.to(device)
    #     # _ = model(images)

    #     image, mask_true = data['image'], data['mask']
    #     # move images and labels to correct device and type
    #     image = image.to(device=device, dtype=torch.float32, memory_format=torch.channels_last)
    #     mask_true = mask_true.to(device=device, dtype=torch.long)

    #     # predict the mask
    #     mask_pred = model(image)

    #     i += 1
    
    # correct = 0
    # total = 0
    with torch.no_grad():
        for data in testloader:
            # images, labels = data
            # images = images.to(device)
            # labels = labels.to(device)

            device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
            image, mask_true = data['image'], data['mask']
            # move images and labels to correct device and type
            image = image.to(device=device, dtype=torch.float32, memory_format=torch.channels_last)
            mask_true = mask_true.to(device=device, dtype=torch.long)

            # starter.record()
            torch.cuda.empty_cache()

            if torch.cuda.is_available():
                model.cuda()
                
            # predict the mask
            mask_pred = model(image)
            # outputs = model(images)
            
            # ender.record()
            
            # WAIT FOR GPU SYNC
            # torch.cuda.synchronize()
            # curr_time = starter.elapsed_time(ender)
            # timings.append(curr_time)
            
            # convert to one-hot format
            mask_true = F.one_hot(mask_true, model.n_classes).permute(0, 3, 1, 2).float()
            mask_pred = F.one_hot(mask_pred.argmax(dim=1), model.n_classes).permute(0, 3, 1, 2).float()
            # compute the Dice score, ignoring background
            dice_score1 += multiclass_dice_coeff(mask_pred[:, 1:], mask_true[:, 1:], reduce_batch_first=False)
            # _, predicted = torch.max(outputs.data, 1)
            # total += labels.size(0)
            # correct += (predicted == labels).sum().item()

    # print('Accuracy of the network on the 10000 test images: '+str(100 * correct / total))
    print('Accuracy of the network on the 10000 test images: '+str((dice_score1/max(len(testloader),1))))
    
    # tot = np.sum(timings)
    # mean_syn_per_batch = np.sum(timings) / len(timings)
    # std_syn_per_batch = np.std(timings)
    # print("Total inference time for test data: "+str(tot))
    # print("Mean inference time per test batch: "+str(mean_syn_per_batch))
    # print("Standard deviation of inference times per batch: "+str(std_syn_per_batch))
    model.train()

# %% [markdown]
# # Loading and normalizing images using TorchVision

# %%
import torchvision
import torchvision.transforms as transforms

# %%
# %pip install tqdm
sys.path.append("./fpgmdata/testing")
from data_loading import CarvanaDataset
import os

# trainset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=transforms.Compose([
#                                  transforms.Pad(4),
#                                  transforms.RandomCrop(32),
#                                  transforms.RandomHorizontalFlip(),
#                                  transforms.ToTensor(),
#                                  transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
#                              ]),
#                                         download=True)
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
#                                           shuffle=True, num_workers=2)

# testset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=transforms.Compose([
#             transforms.ToTensor(),
#             transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
#             ]),
#                                        download=True)
# testloader = torch.utils.data.DataLoader(testset,
#                                          batch_size=32,
#                                          shuffle=False, num_workers=2)

# classes = ('plane', 'car', 'bird', 'cat',
#            'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

dataset = CarvanaDataset("./fpgmdata/testing/data/carvana"+'/imgs', "./fpgmdata/testing/data/carvana"+'/masks', scale=1)
dataset=torch.utils.data.Subset(dataset, range(0,100))
# 2. Split into train / validation partitions
val_percent = 0.2
n_val = int(len(dataset) * val_percent)
n_train = len(dataset) - n_val
train_set, val_set = torch.utils.data.random_split(dataset, [n_train, n_val], generator=torch.Generator().manual_seed(0))

# 3. Create data loaders
loader_args = dict(batch_size=1, num_workers=os.cpu_count(), pin_memory=True)

trainloader = torch.utils.data.DataLoader(train_set, shuffle=True, **loader_args)

testloader = torch.utils.data.DataLoader(val_set, shuffle=False, drop_last=True, **loader_args)
# Out:
# Requirement already satisfied: tqdm in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (4.65.0)
# Note: you may need to restart the kernel to use updated packages.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5088/5088 [03:10<00:00, 26.75it/s]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super().__init__()

        # if bilinear, use the normal convolutions to reduce the number of channels
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)


class UNet(nn.Module):
    def __init__(self, n_channels, n_classes, bilinear=False):
        super(UNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        self.inc = DoubleConv(n_channels, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        factor = 2 if bilinear else 1
        self.down4 = Down(512, 1024 // factor)
        self.up1 = Up(1024, 512 // factor, bilinear)
        self.up2 = Up(512, 256 // factor, bilinear)
        self.up3 = Up(256, 128 // factor, bilinear)
        self.up4 = Up(128, 64, bilinear)
        self.outc = OutConv(64, n_classes)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        return logits
    
    def use_checkpointing(self):
        self.inc = torch.utils.checkpoint(self.inc)
        self.down1 = torch.utils.checkpoint(self.down1)
        self.down2 = torch.utils.checkpoint(self.down2)
        self.down3 = torch.utils.checkpoint(self.down3)
        self.down4 = torch.utils.checkpoint(self.down4)
        self.up1 = torch.utils.checkpoint(self.up1)
        self.up2 = torch.utils.checkpoint(self.up2)
        self.up3 = torch.utils.checkpoint(self.up3)
        self.up4 = torch.utils.checkpoint(self.up4)
        self.outc = torch.utils.checkpoint(self.outc)

# %% [markdown]
# # Testing the accuracy of the unpruned model

# %%
import gc
torch.cuda.empty_cache()
gc.collect()

test_model(unpruned_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       2 torch.cuda.empty_cache()
#       3 gc.collect()
# ----> 5 test_model(unpruned_model)
#
# Cell In[5], line 73, in test_model(model)
#      67         dice_score1 += multiclass_dice_coeff(mask_pred[:, 1:], mask_true[:, 1:], reduce_batch_first=False)
#      68         # _, predicted = torch.max(outputs.data, 1)
#      69         # total += labels.size(0)
#      70         # correct += (predicted == labels).sum().item()
#      71
#      72 # print('Accuracy of the network on the 10000 test images: '+str(100 * correct / total))
# ---> 73 print('Accuracy of the network on the 10000 test images: '+str((dice_score1/max(len(testloader),1).float())))
#      75 # tot = np.sum(timings)
#      76 # mean_syn_per_batch = np.sum(timings) / len(timings)
#      77 # std_syn_per_batch = np.std(timings)
#      78 # print("Total inference time for test data: "+str(tot))
#      79 # print("Mean inference time per test batch: "+str(mean_syn_per_batch))
#      80 # print("Standard deviation of inference times per batch: "+str(std_syn_per_batch))
#      81 model.train()
#
# AttributeError: 'int' object has no attribute 'float'

# %%
torch.cuda.empty_cache()
del unpruned_model

# %% [markdown]
# # Loading the pruned (only zeroed out) model

# %%
# pruned_model = vgg().to(device)

pruned_model = UNet(n_channels=3, n_classes=2)

pruned_model.load_state_dict(torch.load("./logs/unet_pretrain/prune_precfg_epoch40_varience1/checkpoint.pth.tar")['state_dict'])

# %% [markdown]
# # Saving the pruned (only zeroed out) model

# %%
torch.save(pruned_model, './unet_carvana_pruned_net.pth') # without .state_dict

# %% [markdown]
# # Let's test the accuracy of the pruned (only zeroed out) model

# %%
import gc
torch.cuda.empty_cache()
gc.collect()

test_model(pruned_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 torch.cuda.empty_cache()
#       3 gc.collect()
# ----> 5 test_model(pruned_model)
#
# NameError: name 'pruned_model' is not defined

# %% [markdown]
# # Changing the architecture

# %%
# !pip install torch-pruning
import torch_pruning as tp
    
for name, module in pruned_model.named_modules():
    if isinstance(module, torch.nn.Conv2d): #Iterating over all the conv2d layers of the model
        channel_indices = [] #Stores indices of the channels to prune within this conv layer
        t = module.weight.clone().detach()
        t = t.reshape(t.shape[0], -1)
        z = torch.all(t == 0, dim=1)
        z = z.tolist()
        
        for i, flag in enumerate(z):
            if(flag):
                channel_indices.append(i)

        if(channel_indices == []):
            continue
        
        # 1. build dependency graph for vgg
        DG = tp.DependencyGraph().build_dependency(pruned_model, example_inputs=torch.randn(1,3,32,32).to(device))

        # 2. Specify the to-be-pruned channels. Here we prune those channels indexed by idxs.
        group = DG.get_pruning_group(module, tp.prune_conv_out_channels, idxs=channel_indices)
        #print(group)

        # 3. prune all grouped layers that are coupled with the conv layer (included).
        if DG.check_pruning_group(group): # avoid full pruning, i.e., channels=0.
            group.prune()
    
# 4. Save & Load
pruned_model.zero_grad() # We don't want to store gradient information
torch.save(pruned_model, './unet_carvana_arch_pruned_net.pth') # without .state_dict

# %% [markdown]
# # Let's test the accuracy of the pruned model after the architecture modifications

# %%
test_model(pruned_model)

# %% [markdown]
# # Arch pruned model reload check

# %%
reloaded_model = torch.load('./vgg_cifar10_arch_pruned_net.pth')

# %%
test_model(reloaded_model)
